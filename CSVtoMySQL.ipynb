# %%
import mysql.connector
import pandas as pd

# %%
dataset = pd.read_csv('dataset.csv')
dataset.head()
# Out:
#             Disease   Symptom_1              Symptom_2              Symptom_3  \
# 0  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 1  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 2  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 3  Fungal infection     itching              skin_rash    dischromic _patches
# 4  Fungal infection     itching              skin_rash   nodal_skin_eruptions
#
#               Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0   dischromic _patches       NaN       NaN       NaN       NaN       NaN
# 1                   NaN       NaN       NaN       NaN       NaN       NaN
# 2                   NaN       NaN       NaN       NaN       NaN       NaN
# 3                   NaN       NaN       NaN       NaN       NaN       NaN
# 4                   NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
import csv

# %%
try:
    connection = mysql.connector.connect(host='localhost', database='new_database', user='root', password='brihad1692')

    mySql_Create_Table_Query = """CREATE TABLE diseases( 
                                                        Disease varchar(250),
                                                        Symptom_1 varchar(250),
                                                        Symptom_2 varchar(250),
                                                        Symptom_3 varchar(250),
                                                        Symptom_4 varchar(250),
                                                        Symptom_5 varchar(250),
                                                        Symptom_6 varchar(250),
                                                        Symptom_7 varchar(250),
                                                        Symptom_8 varchar(250),
                                                        Symptom_9 varchar(250),
                                                        Symptom_10 varchar(250),
                                                        Symptom_11 varchar(250),
                                                        Symptom_12 varchar(250),
                                                        Symptom_13 varchar(250),
                                                        Symptom_14 varchar(250),
                                                        Symptom_15 varchar(250),
                                                        Symptom_16 varchar(250),
                                                        Symptom_17 varchar(250),
                                                        Vacant varchar(10)
                                                        ) """

    cursor = connection.cursor()
    result = cursor.execute(mySql_Create_Table_Query)
    print("diseases Table created successfully ")



except mysql.connector.Error as error:
    print("Failed to create table in MySQL: {}".format(error))

finally:
    if connection.is_connected():
        cursor.close()
        connection.close()
        print("MySQL connection is closed")
# Out:
# diseases Table created successfully
# MySQL connection is closed

# %%
dataset.head()
# Out:
#             Disease   Symptom_1              Symptom_2              Symptom_3  \
# 0  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 1  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 2  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 3  Fungal infection     itching              skin_rash    dischromic _patches
# 4  Fungal infection     itching              skin_rash   nodal_skin_eruptions
#
#               Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0   dischromic _patches       NaN       NaN       NaN       NaN       NaN
# 1                   NaN       NaN       NaN       NaN       NaN       NaN
# 2                   NaN       NaN       NaN       NaN       NaN       NaN
# 3                   NaN       NaN       NaN       NaN       NaN       NaN
# 4                   NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
entries = ""
counter = 1

with open('dataset.csv') as file_obj:
    heading = next(file_obj)
    reader_obj = csv.reader(file_obj)
    for row in reader_obj:
        #print(row)
        for value in row:
            #print(value)
            entries = entries + "'" + value + "'" + ", "
            #print(entries)
        try:
            connection = mysql.connector.connect(host='localhost', database='new_database', user='root', password='brihad1692')

            sql_insert_stmt = "insert into diseases values(" + entries + " '');"

            print(sql_insert_stmt)
            
            entries = ""
            
            cursor = connection.cursor()
            result = cursor.execute(sql_insert_stmt)
            print(f"inserted {counter} entries")
            counter = counter + 1



        except mysql.connector.Error as error:
            print("Failed to add value in MySQL: {}".format(error))

        finally:
            if connection.is_connected():
                cursor.close()
                connection.close()
                print("MySQL connection is closed")
# Out:
# insert into diseases values('Fungal infection', 'itching', ' skin_rash', ' nodal_skin_eruptions', ' dischromic _patches', '', '', '', '', '', '', '', '', '', '', '', '', '',  '');
# inserted 1 entries
# MySQL connection is closed
# insert into diseases values('Fungal infection', ' skin_rash', ' nodal_skin_eruptions', ' dischromic _patches', '', '', '', '', '', '', '', '', '', '', '', '', '', '',  '');
# inserted 2 entries
# MySQL connection is closed
# insert into diseases values('Fungal infection', 'itching', ' nodal_skin_eruptions', ' dischromic _patches', '', '', '', '', '', '', '', '', '', '', '', '', '', '',  '');
# inserted 3 entries
# MySQL connection is closed
# insert into diseases values('Fungal infection', 'itching', ' skin_rash', ' dischromic _patches', '', '', '', '', '', '', '', '', '', '', '', '', '', '',  '');
# inserted 4 entries
# MySQL connection is closed
# ...
